# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_excel('Data_Science_Internship.xlsx')

# %%
df.head()
# Out:
#    Unnamed: 0                                           Agent_id status  \
# 0         0.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
# 1         1.0  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST
# 2         2.0  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST
# 3         3.0  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST
# 4         4.0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST
#
#       lost_reason                budget                                lease  \
# 0  Not responding                   NaN                                  NaN
# 1      Low budget                   NaN                                  NaN
# 2  Not responding  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks
# 3      Low budget                   0-0                                  0.0
# 4       Junk lead                   NaN                                  NaN
#
#       movein                                             source  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Agent_id', 'status', 'lost_reason', 'budget', 'lease',
#        'movein', 'source', 'source_city', 'source_country', 'utm_source',
#        'utm_medium', 'des_city', 'des_country', 'room_type', 'lead_id'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.head()
# Out:
#                                             Agent_id status     lost_reason  \
# 0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST  Not responding
# 1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST      Low budget
# 2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST  Not responding
# 3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST      Low budget
# 4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST       Junk lead
#
#                  budget                                lease     movein  \
# 0                   NaN                                  NaN        NaT
# 1                   NaN                                  NaN        NaT
# 2  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks 2022-08-31
# 3                   0-0                                  0.0        NaT
# 4                   NaN                                  NaN        NaT
#
#                                               source  \
# ...

# %%
df.shape
# Out:
# (46608, 15)

# %%
np.sum(df.isnull())
# Out:
# Agent_id              0
# status                0
# lost_reason        3364
# budget             3700
# lease              2341
# movein            13638
# source                0
# source_city           0
# source_country        0
# utm_source            0
# utm_medium            0
# des_city              0
# des_country           0
# room_type         23547
# lead_id               0
# dtype: int64

# %%
df['room_type'].unique()
# Out:
# array([nan, 'Ensuite', 'Entire Place', 'Studio', 'Twin-Studio',
#        'Non-Ensuite'], dtype=object)

# %%
df['status'].unique()
# Out:
# array(['LOST', 'WON', 'OPPORTUNITY', 'CONTACTED', 'PROCESSING',
#        'IMPORTANT'], dtype=object)

# %%
sns.countplot(x='status',data=df,palette='magma')
plt.tight_layout();

# %%
np.sum(df.isnull())
# Out:
# Agent_id              0
# status                0
# lost_reason        3364
# budget             3700
# lease              2341
# movein            13638
# source                0
# source_city           0
# source_country        0
# utm_source            0
# utm_medium            0
# des_city              0
# des_country           0
# room_type         23547
# lead_id               0
# dtype: int64

# %%
df.drop('room_type',axis=1,inplace=True)

# %%
np.sum(df.isnull())
# Out:
# Agent_id              0
# status                0
# lost_reason        3364
# budget             3700
# lease              2341
# movein            13638
# source                0
# source_city           0
# source_country        0
# utm_source            0
# utm_medium            0
# des_city              0
# des_country           0
# lead_id               0
# dtype: int64

# %%
for i in range(len(df.columns)):
    print(df.columns[i],":",df[df.columns[i]].nunique(),'>>>>>',df.dtypes[i])
# Out:
# Agent_id : 120 >>>>> object
# status : 6 >>>>> object
# lost_reason : 30 >>>>> object
# budget : 1840 >>>>> object
# lease : 311 >>>>> object
# movein : 477 >>>>> datetime64[ns, UTC]
# source : 683 >>>>> object
# source_city : 4336 >>>>> object
# source_country : 186 >>>>> object
# utm_source : 35 >>>>> object
# utm_medium : 64 >>>>> object
# des_city : 220 >>>>> object
# des_country : 15 >>>>> object

# %%
df.head()
# Out:
#                                             Agent_id status     lost_reason  \
# 0  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST  Not responding
# 1  299ae77a4ef350ae0dd37d6bba1c002d03444fb1edb236...   LOST      Low budget
# 2  c213697430c006013012dd2aca82dd9732aa0a1a6bca13...   LOST  Not responding
# 3  eac9815a500f908736d303e23aa227f0957177b0e6756b...   LOST      Low budget
# 4  1deba9e96f404694373de9749ddd1ca8aa7bb823145a6f...   LOST       Junk lead
#
#                  budget                                lease     movein  \
# 0                   NaN                                  NaN        NaT
# 1                   NaN                                  NaN        NaT
# 2  £121 - £180 Per Week  Full Year Course Stay 40 - 44 weeks 2022-08-31
# 3                   0-0                                  0.0        NaT
# 4                   NaN                                  NaN        NaT
#
#                                               source  \
# ...

# %%
df.drop('lead_id',axis=1,inplace=True)

# %%
df.movein = pd.to_datetime(df.movein, errors='coerce',utc=True)
